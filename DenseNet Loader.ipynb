# %% [markdown]
# import torch

# %%
import torch

# %%
import torch.nn as nn
from torchvision import datasets, models,transforms
from torch.optim import lr_scheduler
import torchvision.models as models 
import time 
import os 
import copy

# %%
model_conv = models.densenet201(pretrained=True)

# %%
model_conv.layers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-860ef38c39ad> in <module>
# ----> 1 model_conv.layers
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     537                 return modules[name]
#     538         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 539             type(self).__name__, name))
#     540
#     541     def __setattr__(self, name, value):
#
# AttributeError: 'DenseNet' object has no attribute 'layers'

# %%
model_conv.features[:-1]
# Out:
# Sequential(
#   (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu0): ReLU(inplace)
#   (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (denseblock1): _DenseBlock(
#     (denselayer1): _DenseLayer(
#       (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace)
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU(inplace)
#       (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (denselayer2): _DenseLayer(
#       (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace)
# ...

# %%
for ft in model_conv.parameters():
    ft.requires_grad = False

# %%
features = list(model_conv.children())[:-1]
features = nn.Sequential(*features)

# %%
pool = nn.MaxPool2d(2)
_ch = 64*32
fc1 = nn.Linear(_ch, 11)
fc2 = nn.Linear(_ch, 168)
fc2 = nn.Linear(_ch, 7)
